# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadAbdullah80/Velocity-Solutions/blob/main/Week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##  AI vs Machine Learning vs Deep Learning

# %% [markdown]
# ### 🔹 Artificial Intelligence (AI)
# Artificial Intelligence is a broad field of computer science focused on creating machines that can mimic human intelligence. This includes tasks like problem-solving, decision-making, understanding language, and recognizing patterns. AI systems can be **rule-based** or **learning-based**, and they don't always require data to function.
#
# **Example:** A rule-based chatbot that answers questions based on fixed rules.
#
# ---
#
# ### 🔹 Machine Learning (ML)
# Machine Learning is a subfield of AI that allows machines to learn from data and improve over time without being explicitly programmed. It uses algorithms to find patterns in data and make predictions or decisions.
#
# **Example:** A spam filter that learns from past emails to detect spam messages.
#
# ---
#
# ### 🔹 Deep Learning (DL)
# Deep Learning is a subfield of Machine Learning that uses **artificial neural networks** with many layers (hence "deep"). It is especially powerful in handling complex data like images, audio, and text. Deep learning models often require large datasets and high computing power.
#
# **Example:** A facial recognition system that identifies people from photos using neural networks.
#
# ---
#
# ### 🔁 Summary Table
#
# | Concept         | Field Of         | Key Idea                                | Example                     |
# |----------------|------------------|------------------------------------------|-----------------------------|
# | AI             | Parent Field     | Machines mimicking human intelligence   | Rule-based chatbot          |
# | ML             | Subset of AI     | Learning from data                      | Spam email classifier       |
# | DL             | Subset of ML     | Neural networks with many layers        | Image recognition system    |

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Practice

# %%
data = ['a','e','i','o','u']
series = pd.Series(data)
print(series)
# Out:
# 0    a
# 1    e
# 2    i
# 3    o
# 4    u
# dtype: object

# %%
data = [('a',1),('e',2),('i',3),('o',4),('u',5)]
series = pd.DataFrame(data, columns=['Vowels',"Index"])
series
# Out:
#   Vowels  Index
# 0      a      1
# 1      e      2
# 2      i      3
# 3      o      4
# 4      u      5

# %%
series.dtypes
# Out:
# Vowels    object
# Index      int64
# dtype: object

# %%
data = pd.read_csv('sample_data/california_housing_test.csv')
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
data.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
data.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
data.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
data['households']
# Out:
# 0        606.0
# 1        277.0
# 2        495.0
# 3         11.0
# 4        237.0
#          ...
# 2995     607.0
# 2996    1036.0
# 2997     220.0
# 2998      14.0
# 2999     260.0
# Name: households, Length: 3000, dtype: float64

# %%
data.loc[11]
# Out:
# longitude              -119.1200
# latitude                 35.8500
# housing_median_age       37.0000
# total_rooms             736.0000
# total_bedrooms          166.0000
# population              564.0000
# households              138.0000
# median_income             2.4167
# median_house_value    58300.0000
# Name: 11, dtype: float64

# %%
data.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
data = data[['housing_median_age','total_rooms','population','households']]

# %%
data
# Out:
#       housing_median_age  total_rooms  population  households
# 0                   27.0       3885.0      1537.0       606.0
# 1                   43.0       1510.0       809.0       277.0
# 2                   27.0       3589.0      1484.0       495.0
# 3                   28.0         67.0        49.0        11.0
# 4                   19.0       1241.0       850.0       237.0
# ...                  ...          ...         ...         ...
# 2995                23.0       1450.0      1258.0       607.0
# 2996                27.0       5257.0      3496.0      1036.0
# 2997                10.0        956.0       693.0       220.0
# 2998                40.0         96.0        46.0        14.0
# 2999                42.0       1765.0       753.0       260.0
#
# [3000 rows x 4 columns]

# %%
data.shape
# Out:
# (3000, 4)

# %%
data.query('total_rooms < 1000')
# Out:
#       housing_median_age  total_rooms  population  households
# 3                   28.0         67.0        49.0        11.0
# 10                  45.0        972.0      1288.0       261.0
# 11                  37.0        736.0       564.0       138.0
# 15                  42.0        161.0       157.0        50.0
# 16                  15.0        570.0       189.0       107.0
# ...                  ...          ...         ...         ...
# 2986                42.0        819.0       899.0       228.0
# 2992                52.0        573.0       232.0        92.0
# 2994                35.0        931.0       516.0       174.0
# 2997                10.0        956.0       693.0       220.0
# 2998                40.0         96.0        46.0        14.0
#
# [362 rows x 4 columns]

# %%
data = data.loc[data['total_rooms'] < 1000]

# %%
data.shape
# Out:
# (362, 4)

# %%
data
# Out:
#       housing_median_age  total_rooms  population  households
# 3                   28.0         67.0        49.0        11.0
# 10                  45.0        972.0      1288.0       261.0
# 11                  37.0        736.0       564.0       138.0
# 15                  42.0        161.0       157.0        50.0
# 16                  15.0        570.0       189.0       107.0
# ...                  ...          ...         ...         ...
# 2986                42.0        819.0       899.0       228.0
# 2992                52.0        573.0       232.0        92.0
# 2994                35.0        931.0       516.0       174.0
# 2997                10.0        956.0       693.0       220.0
# 2998                40.0         96.0        46.0        14.0
#
# [362 rows x 4 columns]

# %%
data
# Out:
#       housing_median_age  total_rooms  population  households
# 3                   28.0         67.0        49.0        11.0
# 10                  45.0        972.0      1288.0       261.0
# 11                  37.0        736.0       564.0       138.0
# 15                  42.0        161.0       157.0        50.0
# 16                  15.0        570.0       189.0       107.0
# ...                  ...          ...         ...         ...
# 2986                42.0        819.0       899.0       228.0
# 2992                52.0        573.0       232.0        92.0
# 2994                35.0        931.0       516.0       174.0
# 2997                10.0        956.0       693.0       220.0
# 2998                40.0         96.0        46.0        14.0
#
# [362 rows x 4 columns]

# %%
data.plot(kind='scatter',x='housing_median_age',y='total_rooms')
# Out:
# <Axes: xlabel='housing_median_age', ylabel='total_rooms'>

# %%
data.to_csv('sample_data/processed_california_housing_test.csv',index=False)

# %% [markdown]
# ## Tic Tac Toe

# %% [markdown]
# ### Dataset Overview – Tic-Tac-Toe Endgame
#
# - This dataset contains all possible endgame board positions in Tic-Tac-Toe.
# - Each cell is labeled as:
#   - `x` → player X moved here
#   - `o` → player O moved here
#   - `b` → cell is blank
# - The goal is to predict whether the position is a **win** (`positive`) or **not a win** (`negative`) for X.
# - This kind of dataset helps train AI models to learn patterns in games.
#
# Source: UCI Machine Learning Repository

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/tic-tac-toe/tic-tac-toe.data"

# Define column names based on dataset documentation
columns = ['top-left', 'top-middle', 'top-right',
           'middle-left', 'middle-middle', 'middle-right',
           'bottom-left', 'bottom-middle', 'bottom-right', 'class']

data = pd.read_csv(url, names=columns)

# %%
data
# Out:
#     top-left top-middle top-right middle-left middle-middle middle-right  \
# 0          x          x         x           x             o            o
# 1          x          x         x           x             o            o
# 2          x          x         x           x             o            o
# 3          x          x         x           x             o            o
# 4          x          x         x           x             o            o
# ..       ...        ...       ...         ...           ...          ...
# 953        o          x         x           x             o            o
# 954        o          x         o           x             x            o
# 955        o          x         o           x             o            x
# 956        o          x         o           o             x            x
# 957        o          o         x           x             x            o
#
#     bottom-left bottom-middle bottom-right     class
# ...

# %%
print("Shape of dataset:", data.shape)
print("\nSample rows:")
print(data.head())

print("\nColumn-wise value counts:")
data.describe()
# Out:
# Shape of dataset: (958, 10)
#
# Sample rows:
#   top-left top-middle top-right middle-left middle-middle middle-right  \
# 0        x          x         x           x             o            o
# 1        x          x         x           x             o            o
# 2        x          x         x           x             o            o
# 3        x          x         x           x             o            o
# 4        x          x         x           x             o            o
#
#   bottom-left bottom-middle bottom-right     class
# 0           x             o            o  positive
# 1           o             x            o  positive
# 2           o             o            x  positive
# 3           o             b            b  positive
# 4           b             o            b  positive
#
# Column-wise value counts:
#        top-left top-middle top-right middle-left middle-middle middle-right  \
# count       958        958       958         958           958          958
# ...

# %%
data.to_csv('sample_data/tic-tac-toe.csv',index=False)

# %% [markdown]
# #Car Evaluation

# %% [markdown]
# ### Car Evaluation Dataset – Overview
#
# The Car Evaluation dataset comes from the UCI Machine Learning Repository. It is a categorical dataset designed to evaluate the acceptability of cars based on several criteria:
#
# ###  Features:
# - **buying** – cost of the car (vhigh, high, med, low)
# - **maint** – maintenance cost (vhigh, high, med, low)
# - **doors** – number of doors (2, 3, 4, 5more)
# - **persons** – capacity (2, 4, more)
# - **lug_boot** – size of luggage boot (small, med, big)
# - **safety** – safety rating (low, med, high)
#
# ###  Target:
# - **class** – Car acceptability (unacc, acc, good, vgood)
#
# ###  Why This Dataset?
# This dataset is ideal for:
# - Exploring **categorical data**
# - Applying **classification models**
# - Understanding how different features influence acceptability
#
#
#
# **Use Case:** Build a model or decision rule to recommend whether a car is acceptable based on its features.

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/car/car.data"
columns = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']
data = pd.read_csv(url, names=columns)

# %%
print("Dataset Shape:", data.shape)
print("\nSample Data:")
data.head(2000)
# data.describe()
# Out:
# Dataset Shape: (1728, 7)
#
# Sample Data:
#      buying  maint  doors persons lug_boot safety  class
# 0     vhigh  vhigh      2       2    small    low  unacc
# 1     vhigh  vhigh      2       2    small    med  unacc
# 2     vhigh  vhigh      2       2    small   high  unacc
# 3     vhigh  vhigh      2       2      med    low  unacc
# 4     vhigh  vhigh      2       2      med    med  unacc
# ...     ...    ...    ...     ...      ...    ...    ...
# 1723    low    low  5more    more      med    med   good
# 1724    low    low  5more    more      med   high  vgood
# 1725    low    low  5more    more      big    low  unacc
# 1726    low    low  5more    more      big    med   good
# 1727    low    low  5more    more      big   high  vgood
#
# [1728 rows x 7 columns]

# %% [markdown]
# #Rule Based Agent

# %% [markdown]
# ## 🤖 Rule-Based Tic-Tac-Toe Agent
#
# We built a basic AI agent that scans each board position and checks for a win for 'x'.
#
# ### Logic:
# - If any row, column, or diagonal contains 3 'x' → Predict `'positive'`
# - Else → Predict `'negative'`
#
# ### Key Insight:
# This is a classic example of a **deterministic rule-based agent**. It doesn’t learn from data, but directly checks winning conditions like a human would.
#
# ### Performance:
# We compared the predictions with the actual labels and achieved accuracy using simple logic — showing how effective symbolic AI can be in fixed environments like games.

# %%
# Define column names
columns = ['top-left', 'top-middle', 'top-right',
           'middle-left', 'middle-middle', 'middle-right',
           'bottom-left', 'bottom-middle', 'bottom-right', 'class']

# Load dataset with proper names
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/tic-tac-toe/tic-tac-toe.data"
data = pd.read_csv(url, names=columns)

# Check the first few rows and column names
print(data.columns)
print(data.head())

# Function to check winning condition for 'x'
def rule_based_tictactoe(row):
    # Extract board positions
    board = [ row['top-left'], row['top-middle'], row['top-right'],
        row['middle-left'], row['middle-middle'], row['middle-right'],
        row['bottom-left'], row['bottom-middle'], row['bottom-right']]

    # Rows
    rows = [
        board[0:3],
        board[3:6],
        board[6:9]
    ]

    # Columns
    cols = [
        [board[0], board[3], board[6]],
        [board[1], board[4], board[7]],
        [board[2], board[5], board[8]]
    ]

    # Diagonals
    diags = [
        [board[0], board[4], board[8]],
        [board[2], board[4], board[6]]
    ]

    # All winning lines
    lines = rows + cols + diags

    # If any line has all 'x', then it's a win
    for line in lines:
        if all(cell == 'x' for cell in line):
            return 'positive'
    return 'negative'
data.shape
# Out:
# Index(['top-left', 'top-middle', 'top-right', 'middle-left', 'middle-middle',
#        'middle-right', 'bottom-left', 'bottom-middle', 'bottom-right',
#        'class'],
#       dtype='object')
#   top-left top-middle top-right middle-left middle-middle middle-right  \
# 0        x          x         x           x             o            o
# 1        x          x         x           x             o            o
# 2        x          x         x           x             o            o
# 3        x          x         x           x             o            o
# 4        x          x         x           x             o            o
#
#   bottom-left bottom-middle bottom-right     class
# 0           x             o            o  positive
# 1           o             x            o  positive
# 2           o             o            x  positive
# 3           o             b            b  positive
# 4           b             o            b  positive
# (958, 10)

# %%
data['predicted_class'] = data.apply(rule_based_tictactoe, axis=1)

# %%
# Check how many predictions match the actual class
correct_predictions = (data['class'] == data['predicted_class']).sum()
print(f"Correct Predictions: {correct_predictions}")
# Calculate accuracy
accuracy = (data['class'] == data['predicted_class']).mean()
print(f"Rule-Based Accuracy: {accuracy:.2f}")
# Out:
# Correct Predictions: 958
# Rule-Based Accuracy: 1.00

# %%
data
# Out:
#     top-left top-middle top-right middle-left middle-middle middle-right  \
# 0          x          x         x           x             o            o
# 1          x          x         x           x             o            o
# 2          x          x         x           x             o            o
# 3          x          x         x           x             o            o
# 4          x          x         x           x             o            o
# ..       ...        ...       ...         ...           ...          ...
# 953        o          x         x           x             o            o
# 954        o          x         o           x             x            o
# 955        o          x         o           x             o            x
# 956        o          x         o           o             x            x
# 957        o          o         x           x             x            o
#
#     bottom-left bottom-middle bottom-right     class predicted_class
# ...

# %% [markdown]
# # Search Algorithms

# %% [markdown]
# ## BFS vs DFS - Search Algorithms in AI
# **DFS (Depth-First Search)** and **BFS (Breadth-First Search)** are search algorithms used to explore mazes, trees, or graphs in AI.
#
# ---
#
# ### 🌐 BFS – Breadth-First Search
# - Explores level-by-level (all neighbors first).
# - Uses a **Queue (FIFO)**.
# - ✅ Finds **shortest path** in unweighted graphs.
# - ❗️ Uses more memory.
#
# ---
#
# ### 🕳️ DFS – Depth-First Search
# - Goes deep into one path before backtracking.
# - Uses a **Stack (LIFO)** or recursion.
# - ❌ Doesn't guarantee shortest path.
# - ✅ Uses less memory.
#
# ---
#
# ### 🔄 Quick Comparison
#
# | Feature        | BFS            | DFS             |
# |----------------|----------------|-----------------|
# | Structure      | Queue (FIFO)   | Stack / Recursion |
# | Path Type      | Shortest path  | Any path        |
# | Memory         | Higher         | Lower           |
# | Use Case       | Mazes, routes  | Puzzles, trees  |
#
# ---
#
# ### 💡 Tip:
# - Use **BFS** for shortest path problems.
# - Use **DFS** for exploration or puzzles.

# %% [markdown]
# ## Maze Solver

# %%
rows = int(input("Enter number of rows: "))
cols = int(input("Enter number of columns: "))

maze = []

print("Enter the maze row by row (0=wall, 1=path, 2=goal, 3=start):" )
for i in range(rows):
    row = list(map(int, input(f"Row {i+1}: ").split()))
    maze.append(row)

print(maze)  # Just print it to check for now
# Out:
# Enter number of rows: 4
# Enter number of columns: 4
# Enter the maze row by row (0=wall, 1=path, 2=goal, 3=start):
# Row 1: 3 1 0 2
# Row 2: 1 0 1 1
# Row 3: 1 1 1 0
# Row 4: 0 1 1 1
# [[3, 1, 0, 2], [1, 0, 1, 1], [1, 1, 1, 0], [0, 1, 1, 1]]

# %%
for i in range(rows):
  print(maze[i])
# Out:
# [3, 1, 0, 2]
# [1, 0, 1, 1]
# [1, 1, 1, 0]
# [0, 1, 1, 1]

# %%
start = None
goal = None

for i in range(rows):              # loop through each row
    for j in range(cols):         # loop through each column
        if maze[i][j] == 3:       # 3 means Start
            start = (i, j)
        elif maze[i][j] == 2:     # 2 means Goal
            goal = (i, j)

# %%
print("Start position:", start)
print("Goal position:", goal)
# Out:
# Start position: (0, 0)
# Goal position: (0, 3)

# %%
from collections import deque

# just playing with queue to understant how it works
# Create an empty deque
queue = deque()

# Add some items
queue.append("A")
queue.append("B")
queue.append("C")

print("Queue after appending:", queue)

# Remove items from the front (FIFO)
first = queue.pop()
print("Removed:", first)

second = queue.popleft()
print("Removed:", second)

print("Queue now:", queue)
# Out:
# Queue after appending: deque(['A', 'B', 'C'])
# Removed: C
# Removed: A
# Queue now: deque(['B'])

# %% [markdown]
# ### *BFS*

# %%
def bfs(maze, start, goal):
    rows = len(maze)
    cols = len(maze[0])
    directions = [(-1,0), (1,0), (0,-1), (0,1)]  # up, down, left, right

    visited = set()
    queue = deque()
    queue.append((start, [start]))  # (current_position, path_so_far)

    while queue:
        current, path = queue.popleft()

        if current == goal:
            return path  # FOUND GOAL

        x, y = current
        for dx, dy in directions:
            nx, ny = x + dx, y + dy


            if 0 <= nx < rows and 0 <= ny < cols:        # inside maze
                if maze[nx][ny] != 0 and (nx, ny) not in visited:  # not wall, not visited
                    visited.add((nx, ny))                 # mark visited
                    queue.append(((nx, ny), path + [(nx, ny)]))  # add new path

    return None  # No path found

# %%
path = bfs(maze, start, goal)
print("Path:", path)
# Out:
# Path: [(0, 0), (1, 0), (2, 0), (2, 1), (2, 2), (1, 2), (1, 3), (0, 3)]

# %%
def draw_maze_with_path(maze, path):
    visual = [[' ' for _ in row] for row in maze]

    for i in range(len(maze)):
        for j in range(len(maze[0])):
            if maze[i][j] == 0:
                visual[i][j] = '#'
            elif maze[i][j] == 3:
                visual[i][j] = 'S'
            elif maze[i][j] == 2:
                visual[i][j] = 'G'
            else:
                visual[i][j] = ' '  # will be replaced if it's in path

    #  Now mark the path (excluding start and goal)
    for i in range(1, len(path)-1):  # skip start and goal
        x, y = path[i]
        px, py = path[i-1]

        if x == px:
            visual[x][y] = '_'  # moved horizontally
        else:
            visual[x][y] = '|'  # moved vertically

    #  Finally, print the visual grid
    print("\nMaze with Path:")
    for row in visual:
        print(" ".join(row))

# %%
if path:
    draw_maze_with_path(maze, path)
else:
    print("No path found!")
# Out:
# Maze with Path:
# S   # G
# | # | _
# | _ _ #
# #

# %% [markdown]
# ### DFS

# %%
def dfs(maze, current, goal, visited, path, rows, cols):
    x, y = current

    # Out of bounds or hitting a wall or already visited
    if (x < 0 or x >= rows or y < 0 or y >= cols or
        maze[x][y] == 0 or (x, y) in visited):
        return False

    # Mark current cell
    visited.add((x, y))
    path.append((x, y))

    # Goal check
    if current == goal:
        return True

    # Explore all directions
    directions = [(-1,0), (1,0), (0,-1), (0,1)]
    for dx, dy in directions:
        nx, ny = x + dx, y + dy
        if dfs(maze, (nx, ny), goal, visited, path, rows, cols):
            return True

    # Dead end: Show attempted path
    draw_maze_with_path(maze, path.copy())
    path.pop()
    return False

# %%
visited = set()
path = []

if dfs(maze, start, goal, visited, path, rows, cols):
    print("\nFinal Path (DFS found the goal):")
    draw_maze_with_path(maze, path)
else:
    print("\nNo path found using DFS.")
# Out:
# Final Path (DFS found the goal):
#
# Maze with Path:
# S   # G
# | # | _
# | _ | #
# # | _
